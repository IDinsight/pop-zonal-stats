# %% [markdown]
# ## Setup

# %%
import pandas as pd
from pathlib import Path

# %%
# Set paths to data folders
path = Path.cwd()
input1_path = path / "Output_Data"
input2_path = path / "Output_Data" /"Updated_outputs"
output_path = path / "Deliverable"

# %%
writer = pd.ExcelWriter(output_path / "Givewell Output Tables.xlsx" , engine = 'openpyxl')

# %% [markdown]
# ## Per Country Combinations

# %% [markdown]
# ### Data Cleaning
# ~ To match the admin level names in the charity submitted data

# %%
nigeria_mc= pd.read_csv(input1_path/ "mc_nigeria_output.csv")
#names to rename
levels_renaming = {
    "Dange-Shuni" : "Dange Shuni",
    "Wamako" : "Wamakko",
    "Kala/Balge" : "Kala Balge",
    "Maiduguri" : "Maiduguri M.C.",
    "Arewa-Dandi" : "Arewa Dandi",
    "Barikin Ladi" : "Barkin Ladi",
    "Nasarawa-Eggon" : "Nasarawa Egon",
    "Askira/Uba" : "Askira-Uba",
    }

nigeria_mc["ADM2_EN"]=nigeria_mc["ADM2_EN"].replace(levels_renaming)
nigeria_mc.to_csv(input2_path / "clean_mc_nigeria_output.csv")

# %%
chad_mc= pd.read_csv(input1_path/ "mc_chad_output.csv")
#names to rename
levels_renaming = {
    "Chaddra" : "Chadra",
    "Michemire" : "Michemere",
    "Ba Illi" : "Ba-Illi",
    "Moulkou" : "Moulkou**",
    "Ndjamena-Centre" : "N'Djamena Centre",
    "Ndjamena-Est" : "N'Djamena Est",
    "Ndjamena-Nord" : "N'Djamena Nord",
    "Ndjamena-Sud" : "N'Djamena Sud",    
    }

chad_mc["District"]=chad_mc["District"].replace(levels_renaming)
chad_mc.to_csv(input2_path / "clean_mc_chad_output.csv")

# %%
burkinafaso_mc= pd.read_csv(input1_path/ "mc_burkinafaso_output.csv")
#names to rename
levels_renaming = {
    "NONGR-MASSOUM" : "NONGR-MASSOM"  ,
    "KONGOUSSI" : "KOUNGOUSSI"  ,
    "PO" : "Pô",
    "SAPONE" : "Saponé",
    "DANDE" : "Dandé",
    "DO" : "Dô",
    "HOUNDE" : "Houndé",
    "KARANGASSO - VIGUE" : "Karangasso Vigué",
    "BOUSSE" : "Boussé",
    "ZINIARE" : "Ziniaré",
    }

burkinafaso_mc["NOMDEP"]=burkinafaso_mc["NOMDEP"].replace(levels_renaming)
burkinafaso_mc.to_csv(input2_path / "clean_mc_burkinafaso_output.csv")

# %%
kenya_hki= pd.read_csv(input1_path/ "hki_kenya_output.csv")
#names to rename
levels_renaming = {
    "Elgeyo-Marakwet" : "Elgeyo Marakwet",
    "Tharaka-Nithi" : "Tharaka Nithi",
    }

kenya_hki["ADM1_EN"]=kenya_hki["ADM1_EN"].replace(levels_renaming)
kenya_hki.to_csv(input2_path / "clean_hki_kenya_output.csv")

# %%
nigeria_hki= pd.read_csv(input1_path/ "hki_nigeria_output.csv")
#names to rename
levels_renaming = {
    "Nasarawa" : "Nassarawa",
    }

nigeria_hki["ADM1_EN"]=nigeria_hki["ADM1_EN"].replace(levels_renaming)
nigeria_hki.to_csv(input2_path / "clean_hki_nigeria_output.csv")

# %%
drc_hki= pd.read_csv(input1_path/ "hki_drc_output.csv")
#names to rename
levels_renaming = {
    "Kasaï-Oriental" : "Kasai Oriental",
    "Kongo-Central" : "Kongo Central",
    }

drc_hki["ADM1_FR"]=drc_hki["ADM1_FR"].replace(levels_renaming)
drc_hki.to_csv(input2_path / "clean_hki_drc_output.csv")

# %%
mali_hki= pd.read_csv(input1_path/ "hki_mali_output.csv")
#names to rename
levels_renaming = {
    "Ségou" : "Segou",
    }

mali_hki["ADM1_FR"]=mali_hki["ADM1_FR"].replace(levels_renaming)
mali_hki.to_csv(input2_path / "clean_hki_mali_output.csv")

# %%
##Niger

niger_hki= pd.read_csv(input1_path/ "hki_niger_output.csv")
#names to rename
levels_renaming = {
    "Tillabéri" : "Tillaberi",
    }

niger_hki["adm_01"]=niger_hki["adm_01"].replace(levels_renaming)
niger_hki.to_csv(input2_path / "clean_hki_niger_output.csv")

# %%
# ### Cote'd'Ivoire

# cote_d_ivoire_hki= pd.read_csv(input1_path/ "hki_cote_d_ivoire_output.csv")
# #names to rename
# levels_renaming = {
#     "" : "Abobo-Est",
#     }

# cote_d_ivoire_hki["ADM1_FR"]=cote_d_ivoire_hki["ADM1_FR"].replace(levels_renaming)
# cote_d_ivoire_hki.to_csv(input2_path / "clean_hki_cote_d_ivoire_output.csv")

# %% [markdown]
# ### Malaria Consortium countries

# %% [markdown]
# #### 1. Nigeria

# %% [markdown]
# Read outputs

# %%
nigeria_mc_output= pd.read_csv(input2_path/ "clean_mc_nigeria_output.csv")
nigeria_mc_output
# Out:
#      Unnamed: 0 ADM1_EN   ADM2_EN  \
# 0             0  Bauchi  Alkaleri
# 1             1  Bauchi    Bauchi
# 2             2  Bauchi    Bogoro
# 3             3  Bauchi    Damban
# 4             4  Bauchi    Darazo
# ..          ...     ...       ...
# 137         137  Sokoto   Tangaza
# 138         138  Sokoto    Tureta
# 139         139  Sokoto   Wamakko
# 140         140  Sokoto     Wurno
# 141         141  Sokoto      Yabo
#
#      worldpop_cons_u5_nga_f_0_4_2021_1km_UNadj_constrained_Nigeria_sum  \
# 0                                                37571
# 1                                                59878
# 2                                                13240
# 3                                                21510
# 4                                                38443
# ..                                                 ...
# 137                                              11827
# 138                                              13005
# ...

# %% [markdown]
# Read charity provided estimates

# %%
nigeria_mc_data=pd.read_excel(path /"Data" / "GiveWell Charity Submitted Data.xlsx",sheet_name="MC Nigeria")

# %%
nigeria_mc_data=nigeria_mc_data[["State","LGA","Submitted MC Data for Target Population(3M-59M) in 2021"]]
nigeria_mc_data
# Out:
#       State          LGA  \
# 0    Sokoto        Binji
# 1    Sokoto      Bodinga
# 2    Sokoto  Dange Shuni
# 3    Sokoto         Gada
# 4    Sokoto      Goronyo
# ..      ...          ...
# 127    Kogi   Yagba East
# 128    Kogi   Yagba West
# 129     NaN        Total
# 130     NaN          NaN
# 131     NaN     Source:
#
#     Submitted MC Data for Target Population(3M-59M) in 2021
# 0                                                28726
# 1                                                37757
# 2                                                65736
# 3                                                68675
# 4                                                27237
# ..                                                 ...
# 127                                            43755.1
# 128                                           42393.75
# 129                                                NaN
# 130                                                NaN
# ...

# %% [markdown]
# Rename column names

# %%
nigeria_mc_output=nigeria_mc_output.rename(columns={"ADM1_EN":"State","ADM2_EN": "LGA"})

# %% [markdown]
# Use concat to combine

# %%
nigeria_mc_merged = pd.merge(nigeria_mc_data, nigeria_mc_output, on=["State", "LGA"], how="left")
nigeria_mc_merged
# Out:
#       State          LGA  \
# 0    Sokoto        Binji
# 1    Sokoto      Bodinga
# 2    Sokoto  Dange Shuni
# 3    Sokoto         Gada
# 4    Sokoto      Goronyo
# ..      ...          ...
# 127    Kogi   Yagba East
# 128    Kogi   Yagba West
# 129     NaN        Total
# 130     NaN          NaN
# 131     NaN     Source:
#
#     Submitted MC Data for Target Population(3M-59M) in 2021  Unnamed: 0  \
# 0                                                28726            119.0
# 1                                                37757            120.0
# 2                                                65736            121.0
# 3                                                68675            122.0
# 4                                                27237            123.0
# ..                                                 ...              ...
# 127                                            43755.1             87.0
# 128                                           42393.75             88.0
# ...

# %% [markdown]
# Calculate percentage differences

# %%
nigeria_mc_merged["cons_perc_difference"]=((nigeria_mc_merged["worldpop_cons_3-59_months"]- nigeria_mc_merged["Submitted MC Data for Target Population(3M-59M) in 2021"])/nigeria_mc_merged["Submitted MC Data for Target Population(3M-59M) in 2021"])
nigeria_mc_merged["wopr_perc_difference"]=((nigeria_mc_merged["worldpop_wopr_3-59_months"]- nigeria_mc_merged["Submitted MC Data for Target Population(3M-59M) in 2021"])/nigeria_mc_merged["Submitted MC Data for Target Population(3M-59M) in 2021"])
nigeria_mc_merged["meta_perc_difference"]=((nigeria_mc_merged["facebook_3-59_months"]- nigeria_mc_merged["Submitted MC Data for Target Population(3M-59M) in 2021"])/ nigeria_mc_merged["Submitted MC Data for Target Population(3M-59M) in 2021"])

# %% [markdown]
# Save to file

# %%
ordered_col_names=['State', 'LGA',
       'Submitted MC Data for Target Population(3M-59M) in 2021', 'worldpop_cons_3-59_months','cons_perc_difference',
       'worldpop_wopr_3-59_months', 'wopr_perc_difference', 'facebook_3-59_months',     'meta_perc_difference', ]

# %%
nigeria_mc_merged=nigeria_mc_merged[ordered_col_names]
nigeria_mc_merged
# Out:
#       State          LGA  \
# 0    Sokoto        Binji
# 1    Sokoto      Bodinga
# 2    Sokoto  Dange Shuni
# 3    Sokoto         Gada
# 4    Sokoto      Goronyo
# ..      ...          ...
# 127    Kogi   Yagba East
# 128    Kogi   Yagba West
# 129     NaN        Total
# 130     NaN          NaN
# 131     NaN     Source:
#
#     Submitted MC Data for Target Population(3M-59M) in 2021  \
# 0                                                28726
# 1                                                37757
# 2                                                65736
# 3                                                68675
# 4                                                27237
# ..                                                 ...
# 127                                            43755.1
# 128                                           42393.75
# 129                                                NaN
# 130                                                NaN
# ...

# %%
nigeria_mc_merged.to_excel(writer, sheet_name= "MC_Nigeria",index=False)

# %% [markdown]
# #### 2. Chad

# %% [markdown]
# Read outputs

# %%
chad_mc_output= pd.read_csv(input2_path/ "clean_mc_chad_output.csv")
chad_mc_output
# Out:
#      Unnamed: 0.1  Unnamed: 0           District           RegName  \
# 0               0           0  9e Arrondissement         N'Djamena
# 1               1           1               Abdi           Ouaddai
# 2               2           2             Abeche           Ouaddai
# 3               3           3           Aboudeia           Salamat
# 4               4           4         Abougoudam           Ouaddai
# ..            ...         ...                ...               ...
# 121           121         121              Tissi              Sila
# 122           122         122            Torrock  Mayo Kebbi Ouest
# 123           123         123                Yao             Batha
# 124           124         124               Youe    Mayo Kebbi Est
# 125           125         125              Zouar           Tibesti
#
#                                               geometry  \
# 0    POLYGON Z ((15.04868549500003 12.0863161520000...
# ...

# %% [markdown]
# Read charity provided estimates

# %%
chad_mc_data=pd.read_excel(path /"Data" / "GiveWell Charity Submitted Data.xlsx",sheet_name="MC Chad")

# %%
chad_mc_data=chad_mc_data[["Region","Health District","Submitted Malaria Consortium Data for Target Population in 2017"]]
chad_mc_data
# Out:
#             Region   Health District  \
# 0   Bahr el Ghazal            Chadra
# 1   Bahr el Ghazal         Michemere
# 2   Bahr el Ghazal          Moussoro
# 3   Bahr el Ghazal             Salal
# 4            Batha               Yao
# 5   Chari Baguirmi           Ba-Illi
# 6   Chari Baguirmi            Bousso
# 7   Chari Baguirmi          Dourbali
# 8   Chari Baguirmi          Mandelia
# 9   Chari Baguirmi          Massenya
# 10  Chari Baguirmi             Kouno
# 11    Hadjer Lamis            Bokoro
# 12    Hadjer Lamis              Gama
# 13    Hadjer Lamis             Karal
# 14    Hadjer Lamis              Mani
# 15    Hadjer Lamis         Massaguet
# 16    Hadjer Lamis         Massakory
# 17  Mayo Kebbi Est            Bongor
# 18  Mayo Kebbi Est              Gam*
# 19  Mayo Kebbi Est        Guelendeng
# 20  Mayo Kebbi Est         Moulkou**
# 21       N'Djamena  N'Djamena Centre
# 22       N'Djamena     N'Djamena Est
# 23       N'Djamena    N'Djamena Nord
# ...

# %% [markdown]
# Rename column names

# %%
chad_mc_output=chad_mc_output.rename(columns={"District": "Health District",	"RegName" : "Region"})

# %% [markdown]
# Use concat to combine

# %%
chad_mc_merged=pd.merge(chad_mc_data,chad_mc_output,on=["Health District"])
chad_mc_merged.columns
# Out:
# Index(['Region_x', 'Health District',
#        'Submitted Malaria Consortium Data for Target Population in 2017',
#        'Unnamed: 0.1', 'Unnamed: 0', 'Region_y', 'geometry',
#        'worldpop_cons_u5_tcd_f_0_4_2022_1km_UNadj_constrained_sum',
#        'worldpop_cons_u5_tcd_m_0_4_2022_1km_UNadj_constrained_sum',
#        'worldpop_cons_u5_sum_total', 'worldpop_cons_3-59_months',
#        'tcd_children_under_five_2020', 'facebook_3-59_months'],
#       dtype='object')

# %% [markdown]
# Calculate percentage differences

# %%
chad_mc_output.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'Health District', 'Region', 'geometry',
#        'worldpop_cons_u5_tcd_f_0_4_2022_1km_UNadj_constrained_sum',
#        'worldpop_cons_u5_tcd_m_0_4_2022_1km_UNadj_constrained_sum',
#        'worldpop_cons_u5_sum_total', 'worldpop_cons_3-59_months',
#        'tcd_children_under_five_2020', 'facebook_3-59_months'],
#       dtype='object')

# %%
chad_mc_merged["cons_perc_difference"]  =  ((chad_mc_merged["worldpop_cons_3-59_months"]  -   chad_mc_merged["Submitted Malaria Consortium Data for Target Population in 2017"])  /  chad_mc_merged["Submitted Malaria Consortium Data for Target Population in 2017"])
# chad_mc_merged["wopr_perc_difference"]  =  ((chad_mc_merged["worldpop_wopr_3-59_months"]  -   chad_mc_merged["Submitted Malaria Consortium Data for Target Population in 2017"])  /  chad_mc_merged["Submitted Malaria Consortium Data for Target Population in 2017"])
chad_mc_merged["meta_perc_difference"]  =  ((chad_mc_merged["facebook_3-59_months"]  -   chad_mc_merged["Submitted Malaria Consortium Data for Target Population in 2017"])  /   chad_mc_merged["Submitted Malaria Consortium Data for Target Population in 2017"])

# %% [markdown]
# Save to file

# %%
chad_mc_merged.columns
# Out:
# Index(['Region_x', 'Health District',
#        'Submitted Malaria Consortium Data for Target Population in 2017',
#        'Unnamed: 0.1', 'Unnamed: 0', 'Region_y', 'geometry',
#        'worldpop_cons_u5_tcd_f_0_4_2022_1km_UNadj_constrained_sum',
#        'worldpop_cons_u5_tcd_m_0_4_2022_1km_UNadj_constrained_sum',
#        'worldpop_cons_u5_sum_total', 'worldpop_cons_3-59_months',
#        'tcd_children_under_five_2020', 'facebook_3-59_months',
#        'cons_perc_difference', 'meta_perc_difference'],
#       dtype='object')

# %%
ordered_col_names = [
    'Region_x', 
    'Health District',
    'Submitted Malaria Consortium Data for Target Population in 2017',
    'worldpop_cons_3-59_months',
    'cons_perc_difference',
    'facebook_3-59_months',
    'meta_perc_difference'
]

# %%
chad_mc_merged=chad_mc_merged[ordered_col_names]
chad_mc_merged
# Out:
#           Region_x   Health District  \
# 0   Bahr el Ghazal            Chadra
# 1   Bahr el Ghazal         Michemere
# 2   Bahr el Ghazal          Moussoro
# 3   Bahr el Ghazal             Salal
# 4            Batha               Yao
# 5   Chari Baguirmi           Ba-Illi
# 6   Chari Baguirmi            Bousso
# 7   Chari Baguirmi          Dourbali
# 8   Chari Baguirmi          Mandelia
# 9   Chari Baguirmi          Massenya
# 10  Chari Baguirmi             Kouno
# 11    Hadjer Lamis            Bokoro
# 12    Hadjer Lamis              Gama
# 13    Hadjer Lamis             Karal
# 14    Hadjer Lamis              Mani
# 15    Hadjer Lamis         Massaguet
# 16    Hadjer Lamis         Massakory
# 17  Mayo Kebbi Est            Bongor
# 18  Mayo Kebbi Est        Guelendeng
# 19  Mayo Kebbi Est         Moulkou**
# 20       N'Djamena  N'Djamena Centre
# 21       N'Djamena     N'Djamena Est
# 22       N'Djamena    N'Djamena Nord
# 23       N'Djamena     N'Djamena Sud
#
# ...

# %%
chad_mc_merged.to_excel(writer, sheet_name="MC_Chad", index=False)

# %% [markdown]
# #### 3. Burkina Faso

# %% [markdown]
# Read outputs

# %%
burkinafaso_mc_output= pd.read_csv(input2_path/ "clean_mc_burkinafaso_output.csv")
burkinafaso_mc_output["NOMDEP"]  =  burkinafaso_mc_output["NOMDEP"].str.title()
burkinafaso_mc_output
# Out:
#     Unnamed: 0      NOMDEP  NOMPROVINC  \
# 0            0     Banfora       COMOE
# 1            1  Barsalogho  SANMATENGA
# 2            2      Baskuy     KADIOGO
# 3            3       Batie    NOUMBIEL
# 4            4      Bittou     BOULGOU
# ..         ...         ...         ...
# 65          65    Tougouri  NAMENTENGA
# 66          66        Yako     PASSORE
# 67          67       Zabre     BOULGOU
# 68          68     Ziniaré  OUBRITENGA
# 69          69      Zorgho  GANZOURGOU
#
#     worldpop_cons_u5_bfa_f_0_4_2022_1km_UNadj_constrained_sum  \
# 0                                               37549
# 1                                               18256
# 2                                               26933
# 3                                                8707
# 4                                               12538
# ..                                                ...
# 65                                              20118
# ...

# %% [markdown]
# Read charity provided estimates

# %%
burkinafaso_mc_data  =  pd.read_excel(path /"Data" / "GiveWell Charity Submitted Data.xlsx",sheet_name="MC Burkina Faso")

# %%
burkinafaso_mc_data=burkinafaso_mc_data[["Region","Health district","Submitted Malaria Consortium Data for Target Population in 2021"]]
burkinafaso_mc_data
# Out:
#              Region   Health district  \
# 0          Cascades           Banfora
# 1          Cascades         Mangodara
# 2          Cascades            Sindou
# 3            Centre            Baskuy
# 4            Centre          Bogodogo
# 5            Centre       Boulmiougou
# 6            Centre      Nongr-Massom
# 7            Centre       Sig-Nonghin
# 8       Centre-Nord        Barsalogho
# 9       Centre-Nord            Boulsa
# 10      Centre-Nord         Boussouma
# 11      Centre-Nord              Kaya
# 12      Centre-Nord        Koungoussi
# 13      Centre-Nord          Tougouri
# 14       Centre-Sud        Kombissiri
# 15       Centre-Sud             Manga
# 16       Centre-Sud                Pô
# 17       Centre-Sud            Saponé
# 18    Hauts Bassins             Dafra
# 19    Hauts Bassins             Dandé
# 20    Hauts Bassins                Dô
# 21    Hauts Bassins            Houndé
# 22    Hauts Bassins  Karangasso Vigué
# ...

# %% [markdown]
# Rename column names

# %%
burkinafaso_mc_output=burkinafaso_mc_output.rename(columns={"NOMDEP" : "Health district",	"NOMPROVINC" : "Province"})

# %% [markdown]
# Use concat to combine

# %%
burkinafaso_mc_merged=pd.merge(burkinafaso_mc_data,burkinafaso_mc_output,on=["Health district"])
burkinafaso_mc_merged.columns
# Out:
# Index(['Region', 'Health district',
#        'Submitted Malaria Consortium Data for Target Population in 2021',
#        'Unnamed: 0', 'Province',
#        'worldpop_cons_u5_bfa_f_0_4_2022_1km_UNadj_constrained_sum',
#        'worldpop_cons_u5_bfa_m_0_4_2022_1km_UNadj_constrained_sum',
#        'worldpop_cons_u5_sum_total', 'worldpop_cons_3-59_months',
#        'worldpop_wopr_u5_sum', 'worldpop_wopr_3-59_months', 'facebook_u5_sum',
#        'facebook_3-59_months'],
#       dtype='object')

# %% [markdown]
# Calculate percentage differences

# %%
burkinafaso_mc_merged["cons_perc_difference"]  =  ((burkinafaso_mc_merged["worldpop_cons_3-59_months"]  -   burkinafaso_mc_merged["Submitted Malaria Consortium Data for Target Population in 2021"])  /  burkinafaso_mc_merged["Submitted Malaria Consortium Data for Target Population in 2021"])
burkinafaso_mc_merged["wopr_perc_difference"]  =  ((burkinafaso_mc_merged["worldpop_wopr_3-59_months"]  -   burkinafaso_mc_merged["Submitted Malaria Consortium Data for Target Population in 2021"])  /  burkinafaso_mc_merged["Submitted Malaria Consortium Data for Target Population in 2021"])
burkinafaso_mc_merged["meta_perc_difference"]  =  ((burkinafaso_mc_merged["facebook_3-59_months"]  -   burkinafaso_mc_merged["Submitted Malaria Consortium Data for Target Population in 2021"])  /   burkinafaso_mc_merged["Submitted Malaria Consortium Data for Target Population in 2021"])

# %% [markdown]
# Save to file

# %%
burkinafaso_mc_merged.columns
# Out:
# Index(['Region', 'Health district',
#        'Submitted Malaria Consortium Data for Target Population in 2021',
#        'Unnamed: 0', 'Province',
#        'worldpop_cons_u5_bfa_f_0_4_2022_1km_UNadj_constrained_sum',
#        'worldpop_cons_u5_bfa_m_0_4_2022_1km_UNadj_constrained_sum',
#        'worldpop_cons_u5_sum_total', 'worldpop_cons_3-59_months',
#        'worldpop_wopr_u5_sum', 'worldpop_wopr_3-59_months', 'facebook_u5_sum',
#        'facebook_3-59_months', 'cons_perc_difference', 'wopr_perc_difference',
#        'meta_perc_difference'],
#       dtype='object')

# %%
ordered_col_names = [
    'Region', 
    'Province',
    'Health district',
    'Submitted Malaria Consortium Data for Target Population in 2021',
    'worldpop_cons_3-59_months',
    'cons_perc_difference',
    'worldpop_wopr_3-59_months', 
    'wopr_perc_difference',
    'facebook_3-59_months',
    'meta_perc_difference'
]

# %%
burkinafaso_mc_merged=burkinafaso_mc_merged[ordered_col_names]
burkinafaso_mc_merged
# Out:
#              Region    Province   Health district  \
# 0          Cascades       COMOE           Banfora
# 1          Cascades       COMOE         Mangodara
# 2          Cascades      LERABA            Sindou
# 3            Centre     KADIOGO            Baskuy
# 4            Centre     KADIOGO          Bogodogo
# 5            Centre     KADIOGO       Boulmiougou
# 6            Centre     KADIOGO      Nongr-Massom
# 7            Centre     KADIOGO       Sig-Nonghin
# 8       Centre-Nord  SANMATENGA        Barsalogho
# 9       Centre-Nord  NAMENTENGA            Boulsa
# 10      Centre-Nord  SANMATENGA         Boussouma
# 11      Centre-Nord  SANMATENGA              Kaya
# 12      Centre-Nord         BAM        Koungoussi
# 13      Centre-Nord  NAMENTENGA          Tougouri
# 14       Centre-Sud      BAZEGA        Kombissiri
# 15       Centre-Sud  ZOUNDWEOGO             Manga
# 16       Centre-Sud     NAHOURI                Pô
# 17       Centre-Sud      BAZEGA            Saponé
# ...

# %%
burkinafaso_mc_merged.to_excel(writer, sheet_name="MC_Burkina Faso", index=False)

# %% [markdown]
# ### HKI Countries

# %% [markdown]
# #### Cameroon

# %% [markdown]
# Read outputs

# %%
cameroon_hki_output= pd.read_csv(input1_path/ "hki_cameroon_output.csv")
cameroon_hki_output
# Out:
#       ADM1_EN       ADM1_FR  \
# 0     Adamawa      Adamaoua
# 1      Centre        Centre
# 2        East           Est
# 3   Far-North  Extrême-Nord
# 4    Littoral      Littoral
# 5       North          Nord
# 6  North-West    Nord-Ouest
# 7       South           Sud
# 8  South-West     Sud-Ouest
# 9        West         Ouest
#
#    worldpop_cons_u5_cmr_f_0_4_2022_1km_UNadj_constrained_sum  \
# 0                                             115292
# 1                                             455707
# 2                                              85111
# 3                                             368902
# 4                                             354574
# 5                                             246272
# 6                                             185270
# 7                                              76032
# 8                                             151328
# 9                                             169945
#
# ...

# %% [markdown]
# Read charity provided estimates

# %%
cameroon_hki_data=pd.read_excel(path /"Data" / "GiveWell Charity Submitted Data.xlsx",sheet_name="HKI Cameroon")
cameroon_hki_data
# Out:
#   Admin-Level1  Submitted HKI Data for Target Population in 2021(round 2)
# 0      Adamawa                                             346900
# 1       Centre                                             954481
# 2         East                                             283813
# 3     Littoral                                             543779
# 4         West                                             427963
# 5        South                                             119638
# 6   North-West                                             316093
# 7        North                                             753448
# 8   South-West                                             277503
# 9    Far-North                                            1359459

# %% [markdown]
# Rename column names

# %%
cameroon_hki_output=cameroon_hki_output.rename(columns={"ADM1_EN":"Admin-Level1"})
cameroon_hki_output
# Out:
#   Admin-Level1       ADM1_FR  \
# 0      Adamawa      Adamaoua
# 1       Centre        Centre
# 2         East           Est
# 3    Far-North  Extrême-Nord
# 4     Littoral      Littoral
# 5        North          Nord
# 6   North-West    Nord-Ouest
# 7        South           Sud
# 8   South-West     Sud-Ouest
# 9         West         Ouest
#
#    worldpop_cons_u5_cmr_f_0_4_2022_1km_UNadj_constrained_sum  \
# 0                                             115292
# 1                                             455707
# 2                                              85111
# 3                                             368902
# 4                                             354574
# 5                                             246272
# 6                                             185270
# 7                                              76032
# 8                                             151328
# 9                                             169945
#
# ...

# %% [markdown]
# Merge the files

# %%
cameroon_hki_merged=pd.merge( cameroon_hki_data, cameroon_hki_output, on=["Admin-Level1"])
cameroon_hki_merged.columns
# Out:
# Index(['Admin-Level1',
#        'Submitted HKI Data for Target Population in 2021(round 2)', 'ADM1_FR',
#        'worldpop_cons_u5_cmr_f_0_4_2022_1km_UNadj_constrained_sum',
#        'worldpop_cons_u5_cmr_m_0_4_2022_1km_UNadj_constrained_sum',
#        'worldpop_cons_u5_sum_total', 'worldpop_cons_6-59_months',
#        'facebook_u5_sum', 'facebook_6-59_months'],
#       dtype='object')

# %% [markdown]
# Calculate percentage differences

# %%
cameroon_hki_merged["cons_perc_difference"]   =   ((cameroon_hki_merged["worldpop_cons_6-59_months"]   -   cameroon_hki_merged["Submitted HKI Data for Target Population in 2021(round 2)"])   /   cameroon_hki_merged["Submitted HKI Data for Target Population in 2021(round 2)"])
cameroon_hki_merged["meta_perc_difference"]   =   ((cameroon_hki_merged["facebook_6-59_months"]   -   cameroon_hki_merged["Submitted HKI Data for Target Population in 2021(round 2)"])   /   cameroon_hki_merged["Submitted HKI Data for Target Population in 2021(round 2)"])

# %% [markdown]
# Save to file

# %%
cameroon_hki_merged.columns
# Out:
# Index(['Admin-Level1',
#        'Submitted HKI Data for Target Population in 2021(round 2)', 'ADM1_FR',
#        'worldpop_cons_u5_cmr_f_0_4_2022_1km_UNadj_constrained_sum',
#        'worldpop_cons_u5_cmr_m_0_4_2022_1km_UNadj_constrained_sum',
#        'worldpop_cons_u5_sum_total', 'worldpop_cons_6-59_months',
#        'facebook_u5_sum', 'facebook_6-59_months', 'cons_perc_difference',
#        'meta_perc_difference'],
#       dtype='object')

# %%
ordered_col_names = [
    'Admin-Level1', 
    'Submitted HKI Data for Target Population in 2021(round 2)',
    'worldpop_cons_6-59_months',
    'cons_perc_difference',
    'facebook_6-59_months',
    'meta_perc_difference'
]

# %%
cameroon_hki_merged=cameroon_hki_merged[ordered_col_names]
cameroon_hki_merged
# Out:
#   Admin-Level1  Submitted HKI Data for Target Population in 2021(round 2)  \
# 0      Adamawa                                             346900
# 1       Centre                                             954481
# 2         East                                             283813
# 3     Littoral                                             543779
# 4         West                                             427963
# 5        South                                             119638
# 6   North-West                                             316093
# 7        North                                             753448
# 8   South-West                                             277503
# 9    Far-North                                            1359459
#
#    worldpop_cons_6-59_months  cons_perc_difference  facebook_6-59_months  \
# 0                   205407.0             -0.407878              227574.0
# 1                   811899.9             -0.149381              764569.8
# ...

# %%
cameroon_hki_merged.to_excel(writer, sheet_name="HKI_Cameroon", index=False)

# %% [markdown]
# #### Kenya

# %% [markdown]
# Read outputs

# %%
kenya_hki_output= pd.read_csv(input2_path/ "clean_hki_kenya_output.csv")
kenya_hki_output
# Out:
#     Unnamed: 0          ADM1_EN  \
# 0            0          Baringo
# 1            1            Bomet
# 2            2          Bungoma
# 3            3            Busia
# 4            4  Elgeyo Marakwet
# 5            5             Embu
# 6            6          Garissa
# 7            7         Homa Bay
# 8            8           Isiolo
# 9            9          Kajiado
# 10          10         Kakamega
# 11          11          Kericho
# 12          12           Kiambu
# 13          13           Kilifi
# 14          14        Kirinyaga
# 15          15            Kisii
# 16          16           Kisumu
# 17          17            Kitui
# 18          18            Kwale
# 19          19         Laikipia
# 20          20             Lamu
# 21          21         Machakos
# 22          22          Makueni
# 23          23          Mandera
# 24          24         Marsabit
# 25          25             Meru
# 26          26           Migori
# 27          27          Mombasa
# ...

# %% [markdown]
# Read charity provided estimates

# %%
kenya_hki_data=pd.read_excel(path /"Data" / "GiveWell Charity Submitted Data.xlsx",sheet_name="HKI Kenya")

# %%
kenya_hki_data=kenya_hki_data[["Admin_level1","Submitted HKI Data for Target Population in 2021(Round 1 and 2)"]]
kenya_hki_data
# Out:
#        Admin_level1  \
# 0           Bungoma
# 1   Elgeyo Marakwet
# 2          Kakamega
# 3            Kilifi
# 4         Kirinyaga
# 5             Kwale
# 6             Siaya
# 7      Taita Taveta
# 8     Tharaka Nithi
# 9       Trans Nzoia
# 10      Uasin Gishu
# 11            Bomet
# 12            Busia
# 13             Embu
# 14          Kajiado
# 15           Kiambu
# 16          Makueni
# 17          Muranga
# 18           Nakuru
# 19            Nandi
# 20           Vihiga
# 21          Baringo
# 22          Garissa
# 23         Homa Bay
# 24           Isiolo
# 25          Kericho
# 26            Kisii
# 27           Kisumu
# 28            Kitui
# 29         Laikipia
# 30             Lamu
# 31         Machakos
# 32          Mandera
# 33         Marsabit
# 34             Meru
# 35           Migori
# 36          Mombasa
# 37          Nairobi
# 38            Narok
# 39          Nyamira
# 40          Samburu
# 41       Tana River
# 42          Turkana
# 43            Wajir
# ...

# %% [markdown]
# Rename column names

# %%
kenya_hki_output=kenya_hki_output.rename(columns={"ADM1_EN":"Admin_level1"})

# %% [markdown]
# Use concat to combine

# %%
kenya_hki_merged  =  pd.merge(kenya_hki_output, kenya_hki_data,  on=["Admin_level1"])

# %% [markdown]
# Calculate percentage differences

# %%
kenya_hki_merged["cons_perc_difference"]  =  ((kenya_hki_merged["worldpop_cons_6-59_months"]  -  kenya_hki_merged["Submitted HKI Data for Target Population in 2021(Round 1 and 2)"])  /  kenya_hki_merged["Submitted HKI Data for Target Population in 2021(Round 1 and 2)"])
kenya_hki_merged["wopr_perc_difference"]  =  ((kenya_hki_merged["worldpop_wopr_6-59_months"]  -  kenya_hki_merged["Submitted HKI Data for Target Population in 2021(Round 1 and 2)"])  /  kenya_hki_merged["Submitted HKI Data for Target Population in 2021(Round 1 and 2)"])
kenya_hki_merged["meta_perc_difference"]  =  ((kenya_hki_merged["facebook_6-59_months"]  -  kenya_hki_merged["Submitted HKI Data for Target Population in 2021(Round 1 and 2)"])  /   kenya_hki_merged["Submitted HKI Data for Target Population in 2021(Round 1 and 2)"])

# %% [markdown]
# Save to file

# %%
kenya_hki_merged.columns
# Out:
# Index(['Unnamed: 0', 'Admin_level1',
#        'worldpop_cons_u5_ken_f_0_4_2022_1km_UNadj_constrained_sum',
#        'worldpop_cons_u5_ken_m_0_4_2022_1km_UNadj_constrained_sum',
#        'worldpop_cons_u5_sum_total', 'worldpop_cons_6-59_months',
#        'worldpop_wopr_u5_sum', 'worldpop_wopr_6-59_months', 'facebook_u5_sum',
#        'facebook_6-59_months',
#        'Submitted HKI Data for Target Population in 2021(Round 1 and 2)',
#        'cons_perc_difference', 'wopr_perc_difference', 'meta_perc_difference'],
#       dtype='object')

# %%
ordered_col_names  =  ['Admin_level1',
       'Submitted HKI Data for Target Population in 2021(Round 1 and 2)',
       'worldpop_cons_6-59_months',
       'cons_perc_difference',
       'worldpop_wopr_6-59_months',
       'wopr_perc_difference',
       'facebook_6-59_months',  
       'meta_perc_difference'
         ]

# %%
kenya_hki_merged  =  kenya_hki_merged[ordered_col_names]
kenya_hki_merged
# Out:
#        Admin_level1  \
# 0           Baringo
# 1             Bomet
# 2           Bungoma
# 3             Busia
# 4   Elgeyo Marakwet
# 5              Embu
# 6           Garissa
# 7          Homa Bay
# 8            Isiolo
# 9           Kajiado
# 10         Kakamega
# 11          Kericho
# 12           Kiambu
# 13           Kilifi
# 14        Kirinyaga
# 15            Kisii
# 16           Kisumu
# 17            Kitui
# 18            Kwale
# 19         Laikipia
# 20             Lamu
# 21         Machakos
# 22          Makueni
# 23          Mandera
# 24         Marsabit
# 25             Meru
# 26           Migori
# 27          Mombasa
# 28          Nairobi
# 29           Nakuru
# 30            Nandi
# 31            Narok
# 32          Nyamira
# 33        Nyandarua
# 34            Nyeri
# 35          Samburu
# 36            Siaya
# 37     Taita Taveta
# 38       Tana River
# 39    Tharaka Nithi
# 40      Trans Nzoia
# 41          Turkana
# 42      Uasin Gishu
# 43           Vihiga
# ...

# %%
kenya_hki_merged.to_excel(writer ,sheet_name="HKI_Kenya",index=False)

# %% [markdown]
# #### Guinea

# %% [markdown]
# Read outputs

# %%
guinea_hki_output= pd.read_csv(input1_path/ "hki_guinea_output.csv")
guinea_hki_output
# Out:
#   admin1Name  worldpop_cons_u5_gin_f_0_4_2022_1km_UNadj_constrained_sum  \
# 0       Boke                                             106702
# 1    Conakry                                             164655
# 2    Faranah                                              95038
# 3     Kankan                                             218957
# 4     Kindia                                             180406
# 5       Labe                                              93669
# 6      Mamou                                              67738
# 7  Nzerekore                                             148197
#
#    worldpop_cons_u5_gin_m_0_4_2022_1km_UNadj_constrained_sum  \
# 0                                             103156
# 1                                             159182
# 2                                              91879
# 3                                             211679
# 4                                             174409
# ...

# %% [markdown]
# Read charity provided estimates

# %%
guinea_hki_data=pd.read_excel(path /"Data" / "GiveWell Charity Submitted Data.xlsx",sheet_name="HKI Guinea")
guinea_hki_data
# Out:
#   Admin_level1  Submitted HKI Data for Target Population in 2021(Round 1)  \
# 0      Conakry                                             448854
# 1         Boke                                             248816
# 2        Mamou                                             170395
# 3    Nzerekore                                             366812
# 4      Faranah                                             224702
# 5       Kankan                                             444212
# 6       Kindia                                             461088
# 7         Labe                                             227420
#
#    Submitted HKI Data for Target Population in 2021(Round2)  \
# 0                                             493740
# 1                                             285070
# 2                                             187434
# 3                                             403493
# 4                                             247172
# ...

# %%
guinea_hki_data=guinea_hki_data[["Admin_level1","Submitted HKI Data for Target Population in 2021(Round2)", "Submitted HKI Data for Target Population in 2021(Round 1)"]]
guinea_hki_data
# Out:
#   Admin_level1  Submitted HKI Data for Target Population in 2021(Round2)  \
# 0      Conakry                                             493740
# 1         Boke                                             285070
# 2        Mamou                                             187434
# 3    Nzerekore                                             403493
# 4      Faranah                                             247172
# 5       Kankan                                             488633
# 6       Kindia                                             500892
# 7         Labe                                             250162
#
#    Submitted HKI Data for Target Population in 2021(Round 1)
# 0                                             448854
# 1                                             248816
# 2                                             170395
# 3                                             366812
# 4                                             224702
# ...

# %% [markdown]
# Rename column names

# %%
guinea_hki_output=guinea_hki_output.rename(columns={"admin1Name":"Admin_level1"})

# %% [markdown]
# Use concat to combine

# %%
guinea_hki_merged=pd.merge(guinea_hki_data,guinea_hki_output,on="Admin_level1")

# %% [markdown]
# Calculate percentage differences

# %%
guinea_hki_merged["cons_perc_difference"]  =  ((guinea_hki_merged["worldpop_cons_6-59_months"]  -  guinea_hki_merged["Submitted HKI Data for Target Population in 2021(Round2)"])  /  guinea_hki_merged["Submitted HKI Data for Target Population in 2021(Round2)"])
guinea_hki_merged["wopr_perc_difference"]  =  ((guinea_hki_merged["worldpop_wopr_6-59_months"]  -  guinea_hki_merged["Submitted HKI Data for Target Population in 2021(Round2)"])  / guinea_hki_merged["Submitted HKI Data for Target Population in 2021(Round2)"])
guinea_hki_merged["meta_perc_difference"]  =  ((guinea_hki_merged["facebook_6-59_months"]  -  guinea_hki_merged["Submitted HKI Data for Target Population in 2021(Round2)"])  /  guinea_hki_merged["Submitted HKI Data for Target Population in 2021(Round2)"])

# %% [markdown]
# Save to file

# %%
guinea_hki_merged.columns
# Out:
# Index(['Admin_level1',
#        'Submitted HKI Data for Target Population in 2021(Round2)',
#        'Submitted HKI Data for Target Population in 2021(Round 1)',
#        'worldpop_cons_u5_gin_f_0_4_2022_1km_UNadj_constrained_sum',
#        'worldpop_cons_u5_gin_m_0_4_2022_1km_UNadj_constrained_sum',
#        'worldpop_cons_u5_sum_total', 'worldpop_cons_6-59_months',
#        'worldpop_wopr_u5_sum', 'worldpop_wopr_6-59_months', 'facebook_u5_sum',
#        'facebook_6-59_months', 'cons_perc_difference', 'wopr_perc_difference',
#        'meta_perc_difference'],
#       dtype='object')

# %%
ordered_col_names=[
        'Admin_level1',
       'Submitted HKI Data for Target Population in 2021(Round2)',
       'Submitted HKI Data for Target Population in 2021(Round 1)',
       'worldpop_cons_6-59_months',
       'cons_perc_difference',    
       'worldpop_wopr_6-59_months', 
       'wopr_perc_difference',
       'facebook_6-59_months', 
       'meta_perc_difference' 
 ]

# %%
guinea_hki_merged=guinea_hki_merged[ordered_col_names]
guinea_hki_merged
# Out:
#   Admin_level1  Submitted HKI Data for Target Population in 2021(Round2)  \
# 0      Conakry                                             493740
# 1         Boke                                             285070
# 2        Mamou                                             187434
# 3    Nzerekore                                             403493
# 4      Faranah                                             247172
# 5       Kankan                                             488633
# 6       Kindia                                             500892
# 7         Labe                                             250162
#
#    Submitted HKI Data for Target Population in 2021(Round 1)  \
# 0                                             448854
# 1                                             248816
# 2                                             170395
# 3                                             366812
# 4                                             224702
# ...

# %%
guinea_hki_merged.to_excel(writer ,sheet_name="HKI_Guinea",index=False)

# %% [markdown]
# ####  Nigeria

# %% [markdown]
# Read outputs

# %%
nigeria_hki_output= pd.read_csv(input2_path/ "clean_hki_nigeria_output.csv")
nigeria_hki_output
# Out:
#     Unnamed: 0                    ADM1_EN  \
# 0            0                       Abia
# 1            1                    Adamawa
# 2            2                  Akwa Ibom
# 3            3                    Anambra
# 4            4                     Bauchi
# 5            5                    Bayelsa
# 6            6                      Benue
# 7            7                      Borno
# 8            8                Cross River
# 9            9                      Delta
# 10          10                     Ebonyi
# 11          11                        Edo
# 12          12                      Ekiti
# 13          13                      Enugu
# 14          14  Federal Capital Territory
# 15          15                      Gombe
# 16          16                        Imo
# 17          17                     Jigawa
# 18          18                     Kaduna
# 19          19                       Kano
# 20          20                    Katsina
# ...

# %% [markdown]
# Read charity provided estimates

# %%
nigeria_hki_data=pd.read_excel(path /"Data" / "GiveWell Charity Submitted Data.xlsx",sheet_name="HKI Nigeria")

# %%
nigeria_hki_data=nigeria_hki_data[["Admin_level1","Submitted HKI Data for Target Population in 2021(Round 1 & 2)"]]
nigeria_hki_data
# Out:
#    Admin_level1  Submitted HKI Data for Target Population in 2021(Round 1 & 2)
# 0          Abia                                             738806
# 1       Adamawa                                             875593
# 2     Nassarawa                                            1136577
# 3         Benue                                            1183220
# 4     Akwa Ibom                                            1165171
# 5       Anambra                                            1090229
# 6        Bauchi                                            1219103
# 7       Bayelsa                                             423905
# 8         Borno                                            1082190
# 9   Cross River                                             753135
# 10        Delta                                            1068425
# 11       Ebonyi                                             566618
# 12          Edo                                             838999
# ...

# %% [markdown]
# Rename column names

# %%
nigeria_hki_output=nigeria_hki_output.rename(columns={"ADM1_EN":"Admin_level1"})

# %% [markdown]
# Use concat to combine

# %%
nigeria_hki_merged=pd.merge(nigeria_hki_data,nigeria_hki_output,on=["Admin_level1"])

# %% [markdown]
# Calculate percentage differences

# %%
nigeria_hki_merged["cons_perc_difference"]  = ((nigeria_hki_merged["worldpop_cons_6-59_months"]  - nigeria_hki_merged["Submitted HKI Data for Target Population in 2021(Round 1 & 2)"])  /  nigeria_hki_merged["Submitted HKI Data for Target Population in 2021(Round 1 & 2)"])
nigeria_hki_merged["wopr_perc_difference"]  = ((nigeria_hki_merged["worldpop_wopr_6-59_months"]  -  nigeria_hki_merged["Submitted HKI Data for Target Population in 2021(Round 1 & 2)"])  /  nigeria_hki_merged["Submitted HKI Data for Target Population in 2021(Round 1 & 2)"])
nigeria_hki_merged["meta_perc_difference"]  = ((nigeria_hki_merged["facebook_6-59_months"]  - nigeria_hki_merged["Submitted HKI Data for Target Population in 2021(Round 1 & 2)"])  /  nigeria_hki_merged["Submitted HKI Data for Target Population in 2021(Round 1 & 2)"])

# %% [markdown]
# Save to file

# %%
nigeria_hki_merged.columns
# Out:
# Index(['Admin_level1',
#        'Submitted HKI Data for Target Population in 2021(Round 1 & 2)',
#        'Unnamed: 0',
#        'worldpop_cons_u5_nga_f_0_4_2021_1km_UNadj_constrained_Nigeria_sum',
#        'worldpop_cons_u5_nga_m_0_4_2021_1km_UNadj_constrained_Nigeria_sum',
#        'worldpop_cons_u5_sum_total', 'worldpop_cons_6-59_months',
#        'worldpop_wopr_u5_sum', 'worldpop_wopr_6-59_months', 'facebook_u5_sum',
#        'facebook_6-59_months', 'cons_perc_difference', 'wopr_perc_difference',
#        'meta_perc_difference'],
#       dtype='object')

# %%
ordered_col_names=[
        'Admin_level1',
       'Submitted HKI Data for Target Population in 2021(Round 1 & 2)',
       'worldpop_cons_6-59_months',
       'cons_perc_difference',    
       'worldpop_wopr_6-59_months', 
       'wopr_perc_difference',
       'facebook_6-59_months', 
       'meta_perc_difference' 
 ]

# %%
nigeria_hki_merged=nigeria_hki_merged[ordered_col_names]
nigeria_hki_merged
# Out:
#    Admin_level1  \
# 0          Abia
# 1       Adamawa
# 2     Nassarawa
# 3         Benue
# 4     Akwa Ibom
# 5       Anambra
# 6        Bauchi
# 7       Bayelsa
# 8         Borno
# 9   Cross River
# 10        Delta
# 11       Ebonyi
# 12          Edo
# 13        Ekiti
# 14        Enugu
# 15        Gombe
# 16          Imo
# 17       Jigawa
# 18       Kaduna
# 19         Kano
# 20      Katsina
# 21        Kebbi
# 22         Kogi
# 23        Kwara
# 24        Lagos
# 25        Niger
# 26         Ogun
# 27         Ondo
# 28         Osun
# 29          Oyo
# 30      Plateau
# 31       Rivers
# 32       Sokoto
# 33       Taraba
# 34         Yobe
# 35      Zamfara
#
#     Submitted HKI Data for Target Population in 2021(Round 1 & 2)  \
# 0                                              738806
# 1                                              875593
# 2                                             1136577
# 3                                             1183220
# ...

# %%
nigeria_hki_merged.to_excel(writer ,sheet_name="HKI_Nigeria",index=False)

# %% [markdown]
# ####  DRC

# %% [markdown]
# Read outputs

# %%
drc_hki_output= pd.read_csv(input2_path/ "clean_hki_drc_output.csv")
drc_hki_output
# Out:
#     Unnamed: 0.1  Unnamed: 0         ADM1_FR  \
# 0              0           0        Bas-Uele
# 1              1           1        Equateur
# 2              2           2    Haut-Katanga
# 3              3           3     Haut-Lomami
# 4              4           4       Haut-Uele
# 5              5           5           Ituri
# 6              6           6           Kasaï
# 7              7           7   Kasaï-Central
# 8              8           8  Kasai Oriental
# 9              9           9        Kinshasa
# 10            10          10   Kongo Central
# 11            11          11          Kwango
# 12            12          12           Kwilu
# 13            13          13          Lomami
# 14            14          14         Lualaba
# 15            15          15         Maniema
# 16            16          16      Maï-Ndombe
# 17            17          17         Mongala
# 18            18          18       Nord-Kivu
# 19            19          19     Nord-Ubangi
# ...

# %% [markdown]
# Read charity provided estimates

# %%
drc_hki_data=pd.read_excel(path /"Data" / "GiveWell Charity Submitted Data.xlsx",sheet_name="HKI DRC")
drc_hki_data
# Out:
#       Admin_level1  Submitted HKI Data for Target Population in 2021(Round2)
# 0    Kongo Central                                         739193.000
# 1         Kinshasa                                        1745775.000
# 2   Kasai Oriental                                            928.908
# 3         Bas Uele                                         251345.000
# 4         Equateur                                         458908.000
# 5     Haut Katanga                                        1157024.000
# 6      Haut Lomami                                         745779.000
# 7        Haut Uele                                         384125.000
# 8            Ituri                                        1308159.000
# 9            Kasai                                         855151.000
# 10          Kwango                                         454463.000
# 11           Kwilu                                         990478.000
# ...

# %% [markdown]
# Rename column names

# %%
drc_hki_output=drc_hki_output.rename(columns={"ADM1_FR":"Admin_level1"})

# %% [markdown]
# Use concat to combine

# %%
drc_hki_merged  =  pd.merge(drc_hki_data, drc_hki_output, on=["Admin_level1"])
drc_hki_merged.columns
# Out:
# Index(['Admin_level1',
#        'Submitted HKI Data for Target Population in 2021(Round2)',
#        'Unnamed: 0.1', 'Unnamed: 0', 'geometry',
#        'worldpop_cons_u5_cod_f_0_4_2022_1km_UNadj_constrained_sum',
#        'worldpop_cons_u5_cod_m_0_4_2022_1km_UNadj_constrained_sum',
#        'worldpop_cons_u5_sum_total', 'worldpop_cons_6-59_months',
#        'worldpop_wopr_u5_sum', 'worldpop_wopr_6-59_months',
#        'cod_children_under_five_2020', 'facebook_6-59_months'],
#       dtype='object')

# %% [markdown]
# Calculate percentage differences

# %%
drc_hki_merged["cons_perc_difference"]  = ((drc_hki_merged["worldpop_cons_6-59_months"]  - drc_hki_merged["Submitted HKI Data for Target Population in 2021(Round2)"])  /  drc_hki_merged["Submitted HKI Data for Target Population in 2021(Round2)"])
drc_hki_merged["wopr_perc_difference"]  = ((drc_hki_merged["worldpop_wopr_6-59_months"]  -  drc_hki_merged["Submitted HKI Data for Target Population in 2021(Round2)"])  /  drc_hki_merged["Submitted HKI Data for Target Population in 2021(Round2)"])
drc_hki_merged["meta_perc_difference"]  = ((drc_hki_merged["facebook_6-59_months"]  - drc_hki_merged["Submitted HKI Data for Target Population in 2021(Round2)"])  /  drc_hki_merged["Submitted HKI Data for Target Population in 2021(Round2)"])

# %% [markdown]
# Save to file

# %%
drc_hki_merged.columns
# Out:
# Index(['Admin_level1',
#        'Submitted HKI Data for Target Population in 2021(Round2)',
#        'Unnamed: 0.1', 'Unnamed: 0', 'geometry',
#        'worldpop_cons_u5_cod_f_0_4_2022_1km_UNadj_constrained_sum',
#        'worldpop_cons_u5_cod_m_0_4_2022_1km_UNadj_constrained_sum',
#        'worldpop_cons_u5_sum_total', 'worldpop_cons_6-59_months',
#        'worldpop_wopr_u5_sum', 'worldpop_wopr_6-59_months',
#        'cod_children_under_five_2020', 'facebook_6-59_months',
#        'cons_perc_difference', 'wopr_perc_difference', 'meta_perc_difference'],
#       dtype='object')

# %%
ordered_col_names=[
        'Admin_level1',
       'Submitted HKI Data for Target Population in 2021(Round2)',
       'worldpop_cons_6-59_months',
       'cons_perc_difference',    
       'worldpop_wopr_6-59_months', 
       'wopr_perc_difference',
       'facebook_6-59_months', 
       'meta_perc_difference' 
 ]

# %%
drc_hki_merged  =  drc_hki_merged[ordered_col_names]
drc_hki_merged
# Out:
#       Admin_level1  Submitted HKI Data for Target Population in 2021(Round2)  \
# 0    Kongo Central                                         739193.000
# 1         Kinshasa                                        1745775.000
# 2   Kasai Oriental                                            928.908
# 3         Equateur                                         458908.000
# 4            Ituri                                        1308159.000
# 5           Kwango                                         454463.000
# 6            Kwilu                                         990478.000
# 7          Lualaba                                         505694.000
# 8           Lomami                                         696391.000
# 9          Mongala                                         483629.000
# 10         Maniema                                         511442.000
# 11         Sankuru                                         444172.000
# ...

# %%
drc_hki_merged.to_excel(writer ,sheet_name="HKI_DRC",index=False)

# %% [markdown]
# ####  Mali

# %% [markdown]
# Read outputs

# %%
mali_hki_output= pd.read_csv(input2_path/ "clean_hki_mali_output.csv")
mali_hki_output
# Out:
#    Unnamed: 0.1  Unnamed: 0     ADM1_FR  \
# 0             0           0      Bamako
# 1             1           1         Gao
# 2             2           2       Kayes
# 3             3           3       Kidal
# 4             4           4   Koulikoro
# 5             5           5      Menaka
# 6             6           6       Mopti
# 7             7           7     Sikasso
# 8             8           8       Segou
# 9             9           9  Tombouctou
#
#                                             geometry  \
# 0  POLYGON ((-7.929383644999973 12.68170913700004...
# 1  POLYGON ((0.3757176060000234 18.05625935200004...
# 2  POLYGON ((-9.330083152999975 15.49779234900006...
# 3  POLYGON ((1.2012791060000723 20.72027135400003...
# 4  POLYGON ((-9.000381902999948 15.49747959900003...
# 5  POLYGON ((2.2474526070000707 18.05950322700005...
# 6  POLYGON ((-3.2365822729999536 15.8573512250000...
# 7  POLYGON ((-5.114929024999981 12.65576372200007...
# ...

# %% [markdown]
# Read charity provided estimates

# %%
mali_hki_data=pd.read_excel(path /"Data" / "GiveWell Charity Submitted Data.xlsx",sheet_name="HKI Mali")

# %%
mali_hki_data=mali_hki_data[["Admin_level1","Submitted HKI Data for Target Population in 2021(Round 1 and 2)"]]
mali_hki_data
# Out:
#    Admin_level1  \
# 0         Kayes
# 1         Segou
# 2        Bamako
# 3     Koulikoro
# 4       Sikasso
# 5         Mopti
# 6           Gao
# 7         Kidal
# 8        Menaka
# 9    Tombouctou
# 10     Taoudeni
#
#     Submitted HKI Data for Target Population in 2021(Round 1 and 2)
# 0                                              803253
# 1                                              949223
# 2                                             1971583
# 3                                             1230195
# 4                                             1272457
# 5                                              896758
# 6                                              225744
# 7                                               11351
# 8                                               47013
# 9                                              191328
# 10                                              40802

# %% [markdown]
# Rename column names

# %%
mali_hki_output  =  mali_hki_output.rename(columns={"ADM1_FR":"Admin_level1"})

# %% [markdown]
# Use concat to combine

# %%
mali_hki_merged  =  pd.merge(mali_hki_data, mali_hki_output, on=["Admin_level1"])

# %% [markdown]
# Calculate percentage differences

# %%
mali_hki_merged["cons_perc_difference"]  = ((mali_hki_merged["worldpop_cons_6-59_months"]  - mali_hki_merged["Submitted HKI Data for Target Population in 2021(Round 1 and 2)"])  /  mali_hki_merged["Submitted HKI Data for Target Population in 2021(Round 1 and 2)"])
mali_hki_merged["wopr_perc_difference"]  = ((mali_hki_merged["worldpop_wopr_6-59_months"]  -  mali_hki_merged["Submitted HKI Data for Target Population in 2021(Round 1 and 2)"])  /  mali_hki_merged["Submitted HKI Data for Target Population in 2021(Round 1 and 2)"])
mali_hki_merged["meta_perc_difference"]  = ((mali_hki_merged["facebook_6-59_months"]  - mali_hki_merged["Submitted HKI Data for Target Population in 2021(Round 1 and 2)"])  /  mali_hki_merged["Submitted HKI Data for Target Population in 2021(Round 1 and 2)"])

# %% [markdown]
# Save to file

# %%
mali_hki_merged.columns
# Out:
# Index(['Admin_level1',
#        'Submitted HKI Data for Target Population in 2021(Round 1 and 2)',
#        'Unnamed: 0.1', 'Unnamed: 0', 'geometry',
#        'worldpop_cons_u5_mli_f_0_4_2022_1km_UNadj_constrained_sum',
#        'worldpop_cons_u5_mli_m_0_4_2022_1km_UNadj_constrained_sum',
#        'worldpop_cons_u5_sum_total', 'worldpop_cons_6-59_months',
#        'worldpop_wopr_u5_sum', 'worldpop_wopr_6-59_months',
#        'mli_children_under_five_2020', 'facebook_6-59_months',
#        'cons_perc_difference', 'wopr_perc_difference', 'meta_perc_difference'],
#       dtype='object')

# %%
ordered_col_names  =  [
        'Admin_level1',
        'Submitted HKI Data for Target Population in 2021(Round 1 and 2)',
       'worldpop_cons_6-59_months',
       'cons_perc_difference',    
       'worldpop_wopr_6-59_months', 
       'wopr_perc_difference',
       'facebook_6-59_months', 
       'meta_perc_difference' 
 ]

# %%
mali_hki_merged=mali_hki_merged[ordered_col_names]
mali_hki_merged
# Out:
#   Admin_level1  \
# 0        Kayes
# 1        Segou
# 2       Bamako
# 3    Koulikoro
# 4      Sikasso
# 5        Mopti
# 6          Gao
# 7        Kidal
# 8       Menaka
# 9   Tombouctou
#
#    Submitted HKI Data for Target Population in 2021(Round 1 and 2)  \
# 0                                             803253
# 1                                             949223
# 2                                            1971583
# 3                                            1230195
# 4                                            1272457
# 5                                             896758
# 6                                             225744
# 7                                              11351
# 8                                              47013
# 9                                             191328
#
#    worldpop_cons_6-59_months  cons_perc_difference  worldpop_wopr_6-59_months  \
# 0                   470227.5             -0.414596                  542032.00
# ...

# %%
mali_hki_merged.to_excel(writer ,sheet_name="HKI_Mali",index=False)

# %% [markdown]
# ####  Niger

# %% [markdown]
# Read outputs

# %%
niger_hki_output= pd.read_csv(input2_path/ "clean_hki_niger_output.csv")
niger_hki_output
# Out:
#    Unnamed: 0.1  Unnamed: 0     adm_01  \
# 0             0           0     Agadez
# 1             1           1      Diffa
# 2             2           2      Dosso
# 3             3           3     Maradi
# 4             4           4     Niamey
# 5             5           5     Tahoua
# 6             6           6  Tillaberi
# 7             7           7     Zinder
#
#                                             geometry  \
# 0  POLYGON ((11.989007050000055 23.53318620400006...
# 1  POLYGON ((15.559419827000056 18.00624677600007...
# 2  POLYGON ((3.6684016160000397 11.98401484300006...
# 3  POLYGON ((7.769470215000069 14.42108154300007,...
# 4  POLYGON ((2.0944824220000555 13.61968994100004...
# 5  POLYGON ((4.871293319000074 18.67932348100004,...
# 6  POLYGON ((3.881286621000072 15.689086914000029...
# 7  POLYGON ((12.004882812000062 17.41851806600004...
#
#    worldpop_cons_u5_ner_m_0_4_2022_1km_UNadj_constrained_sum  \
# 0                                              70584
# ...

# %% [markdown]
# Read charity provided estimates

# %%
niger_hki_data=pd.read_excel(path /"Data" / "GiveWell Charity Submitted Data.xlsx",sheet_name="HKI Niger")

# %%
niger_hki_data=niger_hki_data[["Admin_level1","Submitted HKI Data for Target Population in 2021(Round2)"]]
niger_hki_data
# Out:
#   Admin_level1  Submitted HKI Data for Target Population in 2021(Round2)
# 0       Agadez                                             136908
# 1        Diffa                                             288900
# 2        Dosso                                             647530
# 3    Tillaberi                                             844530
# 4       Tahoua                                            1155112
# 5       Maradi                                            1339845
# 6       Niamey                                             334979
# 7       Zinder                                            1458736

# %% [markdown]
# Rename column names

# %%
niger_hki_output=niger_hki_output.rename(columns={"adm_01":"Admin_level1"})

# %% [markdown]
# Use concat to combine

# %%
niger_hki_merged=pd.merge(niger_hki_data,niger_hki_output,on=["Admin_level1"])

# %% [markdown]
# Calculate percentage differences

# %%
niger_hki_merged["cons_perc_difference"]  = ((niger_hki_merged["worldpop_cons_6-59_months"]  - niger_hki_merged["Submitted HKI Data for Target Population in 2021(Round2)"])  /  niger_hki_merged["Submitted HKI Data for Target Population in 2021(Round2)"])
niger_hki_merged["wopr_perc_difference"]  = ((niger_hki_merged["worldpop_wopr_6-59_months"]  -  niger_hki_merged["Submitted HKI Data for Target Population in 2021(Round2)"])  /  niger_hki_merged["Submitted HKI Data for Target Population in 2021(Round2)"])
niger_hki_merged["meta_perc_difference"]  = ((niger_hki_merged["facebook_6-59_months"]  - niger_hki_merged["Submitted HKI Data for Target Population in 2021(Round2)"])  /  niger_hki_merged["Submitted HKI Data for Target Population in 2021(Round2)"])

# %% [markdown]
# Save to file

# %%
niger_hki_merged.columns
# Out:
# Index(['Admin_level1',
#        'Submitted HKI Data for Target Population in 2021(Round2)',
#        'Unnamed: 0.1', 'Unnamed: 0', 'geometry',
#        'worldpop_cons_u5_ner_m_0_4_2022_1km_UNadj_constrained_sum',
#        'worldpop_cons_u5_ner_f_0_4_2022_1km_UNadj_constrained_sum',
#        'worldpop_cons_u5_sum_total', 'worldpop_cons_6-59_months',
#        'worldpop_wopr_u5_sum', 'worldpop_wopr_6-59_months',
#        'ner_children_under_five_2020', 'facebook_6-59_months',
#        'cons_perc_difference', 'wopr_perc_difference', 'meta_perc_difference'],
#       dtype='object')

# %%
ordered_col_names=[
        'Admin_level1',
       'Submitted HKI Data for Target Population in 2021(Round2)',
       'worldpop_cons_6-59_months',
       'cons_perc_difference',    
       'worldpop_wopr_6-59_months', 
       'wopr_perc_difference',
       'facebook_6-59_months', 
       'meta_perc_difference' 
 ]

# %%
niger_hki_merged=niger_hki_merged[ordered_col_names]
niger_hki_merged
# Out:
#   Admin_level1  Submitted HKI Data for Target Population in 2021(Round2)  \
# 0       Agadez                                             136908
# 1        Diffa                                             288900
# 2        Dosso                                             647530
# 3    Tillaberi                                             844530
# 4       Tahoua                                            1155112
# 5       Maradi                                            1339845
# 6       Niamey                                             334979
# 7       Zinder                                            1458736
#
#    worldpop_cons_6-59_months  cons_perc_difference  worldpop_wopr_6-59_months  \
# 0                   129141.0             -0.056732                  108192.65
# 1                   172517.4             -0.402847                  148202.85
# 2                   495722.7             -0.234441                  517097.35
# ...

# %%
niger_hki_merged.to_excel(writer ,sheet_name="HKI_Niger",index=False)

# %% [markdown]
# ####  Cote'd'Ivoire

# %% [markdown]
# Read outputs

# %%
cote_d_ivoire_hki_output= pd.read_csv(input1_path/ "hki_cote_d_ivoire_output.csv")
cote_d_ivoire_hki_output
# Out:
#      Unnamed: 0           ADM2_FR                            ADM1_FR  \
# 0             0        Abengourou                   Indenie-Djuablin
# 1             1           Abidjan        District Autonome D'Abidjan
# 2             2           Aboisso                          Sud-Comoe
# 3             3            Adiaké                          Sud-Comoe
# 4             4            Adzopé                                 Me
# ..          ...               ...                                ...
# 103         103  Yakassé-Attobrou                                 Me
# 104         104      Yamoussoukro  District Autonome De Yamoussoukro
# 105         105     Zouan-Hounien                             Tonkpi
# 106         106        Zoukougbeu                     Haut-Sassandra
# 107         107          Zuénoula                           Marahoue
#
#                                               geometry  \
# 0    POLYGON ((-3.321438832999945 7.03456178600004,...
# ...

# %% [markdown]
# Read charity provided estimates

# %%
cote_d_ivoire_hki_data=pd.read_excel(path /"Data" / "GiveWell Charity Submitted Data.xlsx",sheet_name="HKI Côte dIvoire")
cote_d_ivoire_hki_data.columns
# Out:
# Index(['ADMIN1 ',
#        'Submitted HKI Data for Target Population in 2021-Round 1 &Round 2',
#        'Population according to WorldPop Demographic database 2021',
#        'Percentage difference',
#        ' Population according to WorldPop Top Down Constrained model ',
#        'Percentage difference.1', 'Population according to Facebook HRSL',
#        'Percentage difference.2',
#        ' Population according to WorldPop Bottom-Up ',
#        'Percentage difference.3', 'Average across all alternative estimates',
#        'Percentage difference.4'],
#       dtype='object')

# %%
cote_d_ivoire_hki_data=cote_d_ivoire_hki_data[["ADMIN1 ","Submitted HKI Data for Target Population in 2021-Round 1 &Round 2"]]
# cote_d_ivoire_hki_data2=cote_d_ivoire_hki_data[["Communes*","Submitted HKI Data for Target Population in 2021(SVA ROUTIN-after round1 &2)"]]
cote_d_ivoire_hki_data
# Out:
#         ADMIN1   \
# 0     Abobo-Est
# 1   Abobo-Ouest
# 2        Adzopé
# 3     Agboville
# 4        Akoupé
# ..          ...
# 67         Koro
# 68        Kouto
# 69     Ouaninou
# 70        Touba
# 71    Toulepleu
#
#     Submitted HKI Data for Target Population in 2021-Round 1 &Round 2
# 0                                              330924
# 1                                              327839
# 2                                               57417
# 3                                               82519
# 4                                               49429
# ..                                                ...
# 67                                              15657
# 68                                              42938
# 69                                              13810
# 70                                              23852
# 71                                              18834
#
# [72 rows x 2 columns]

# %% [markdown]
# Rename column names

# %%
cote_d_ivoire_hki_data = cote_d_ivoire_hki_data.rename(columns={"ADMIN1 ": "Admin_level2"})

# %%
cote_d_ivoire_hki_output  =  cote_d_ivoire_hki_output.rename(columns={"ADM1_FR":"Admin_level1", "ADM2_FR" : "Admin_level2" })
cote_d_ivoire_hki_output
# Out:
#      Unnamed: 0      Admin_level2                       Admin_level1  \
# 0             0        Abengourou                   Indenie-Djuablin
# 1             1           Abidjan        District Autonome D'Abidjan
# 2             2           Aboisso                          Sud-Comoe
# 3             3            Adiaké                          Sud-Comoe
# 4             4            Adzopé                                 Me
# ..          ...               ...                                ...
# 103         103  Yakassé-Attobrou                                 Me
# 104         104      Yamoussoukro  District Autonome De Yamoussoukro
# 105         105     Zouan-Hounien                             Tonkpi
# 106         106        Zoukougbeu                     Haut-Sassandra
# 107         107          Zuénoula                           Marahoue
#
#                                               geometry  \
# 0    POLYGON ((-3.321438832999945 7.03456178600004,...
# ...

# %%
# cote_d_ivoire_hki_data2 = cote_d_ivoire_hki_data2.rename(columns={"Communes*": "Admin_level2"})

# %% [markdown]
# Use concat to combine

# %%
cote_d_ivoire_hki_merged  =  pd.merge(cote_d_ivoire_hki_data, cote_d_ivoire_hki_output, on=["Admin_level2"])
# cote_d_ivoire_hki_merged

# %%
cote_d_ivoire_hki_merged.columns
# Out:
# Index(['Admin_level2',
#        'Submitted HKI Data for Target Population in 2021-Round 1 &Round 2',
#        'Unnamed: 0', 'Admin_level1', 'geometry',
#        'worldpop_cons_u5_civ_f_0_4_2022_1km_UNadj_constrained_sum',
#        'worldpop_cons_u5_civ_m_0_4_2022_1km_UNadj_constrained_sum',
#        'worldpop_cons_u5_sum_total', 'worldpop_cons_6-59_months',
#        'civ_children_under_five_2020', 'facebook_6-59_months'],
#       dtype='object')

# %% [markdown]
# Calculate percentage differences

# %%
cote_d_ivoire_hki_merged["cons_perc_difference"]  = ((cote_d_ivoire_hki_merged["worldpop_cons_6-59_months"]  - cote_d_ivoire_hki_merged["Submitted HKI Data for Target Population in 2021-Round 1 &Round 2"])  /  cote_d_ivoire_hki_merged["Submitted HKI Data for Target Population in 2021-Round 1 &Round 2"])
# cote_d_ivoire_hki_merged["wopr_perc_difference"]  = ((cote_d_ivoire_hki_merged["worldpop_wopr_6-59_months"]  -  cote_d_ivoire_hki_merged["Submitted HKI Data for Target Population in 2021-Round 1 &Round 2"])  /  cote_d_ivoire_hki_merged["Submitted HKI Data for Target Population in 2021-Round 1 &Round 2"])
cote_d_ivoire_hki_merged["meta_perc_difference"]  = ((cote_d_ivoire_hki_merged["facebook_6-59_months"]  - cote_d_ivoire_hki_merged["Submitted HKI Data for Target Population in 2021-Round 1 &Round 2"])  /  cote_d_ivoire_hki_merged["Submitted HKI Data for Target Population in 2021-Round 1 &Round 2"])

# %% [markdown]
# Save to file

# %%
cote_d_ivoire_hki_merged.columns
# Out:
# Index(['Admin_level2',
#        'Submitted HKI Data for Target Population in 2021-Round 1 &Round 2',
#        'Unnamed: 0', 'Admin_level1', 'geometry',
#        'worldpop_cons_u5_civ_f_0_4_2022_1km_UNadj_constrained_sum',
#        'worldpop_cons_u5_civ_m_0_4_2022_1km_UNadj_constrained_sum',
#        'worldpop_cons_u5_sum_total', 'worldpop_cons_6-59_months',
#        'civ_children_under_five_2020', 'facebook_6-59_months',
#        'cons_perc_difference', 'meta_perc_difference'],
#       dtype='object')

# %%
ordered_col_names  =  [
        'Admin_level2',
        'Submitted HKI Data for Target Population in 2021-Round 1 &Round 2',
       'worldpop_cons_6-59_months',
       'cons_perc_difference',    
       'facebook_6-59_months', 
       'meta_perc_difference' 
 ]

# %%
cote_d_ivoire_hki_merged  =  cote_d_ivoire_hki_merged[ordered_col_names]
cote_d_ivoire_hki_merged
# Out:
#     Admin_level2  \
# 0         Adzopé
# 1      Agboville
# 2         Akoupé
# 3          Alépé
# 4        Bangolo
# 5         Béoumi
# 6      Biankouma
# 7      Bondoukou
# 8          Botro
# 9          Dabou
# 10        Danané
# 11       Duékoué
# 12   Grand-Lahou
# 13          Kani
# 14      Koun Fao
# 15      Madinani
# 16           Man
# 17      Sakassou
# 18      Sandegue
# 19       Séguéla
# 20       Sikensi
# 21         Tanda
# 22      Tiassalé
# 23       Transua
# 24    Abengourou
# 25       Aboisso
# 26        Adiaké
# 27  Agnibilékrou
# 28       Bocanda
# 29          Buyo
# 30         Daloa
# 31      Dimbokro
# 32          Divo
# 33        Fresco
# 34        Guitry
# 35        Lakota
# 36        Méagui
# 37          Oumé
# 38     Sassandra
# 39        Soubré
# 40         Tabou
# 41       Tiapoum
# 42       Toumodi
# 43    Zoukougbeu
# 44      Zuénoula
# 45     Bloléquin
# 46     Boundiali
# 47       Daoukro
# 48       Katiola
# 49          Koro
# 50         Kouto
# ...

# %%
cote_d_ivoire_hki_merged.to_excel(writer, sheet_name="HKI_Cote dIvoire", index=False)

# %% [markdown]
# ####  Burkina Faso

# %% [markdown]
# Read outputs

# %%
burkinafaso_hki_output= pd.read_csv(input1_path/ "hki_burkina_faso_output.csv")
burkinafaso_hki_output
# Out:
#               ADM1_FR  \
# 0   Boucle du Mouhoun
# 1            Cascades
# 2              Centre
# 3          Centre-Est
# 4         Centre-Nord
# 5        Centre-Ouest
# 6          Centre-Sud
# 7                 Est
# 8       Hauts-Bassins
# 9                Nord
# 10    Plateau-Central
# 11              Sahel
# 12          Sud-Ouest
#
#     worldpop_cons_u5_bfa_f_0_4_2022_1km_UNadj_constrained_sum  \
# 0                                              155894
# 1                                               91047
# 2                                              340002
# 3                                              136239
# 4                                              140212
# 5                                              137553
# 6                                               71235
# 7                                              163718
# 8                                              198771
# 9                                              128313
# ...

# %% [markdown]
# Read charity provided estimates

# %%
burkinafaso_hki_data=pd.read_excel(path /"Data" / "GiveWell Charity Submitted Data.xlsx",sheet_name="HKI Burkina Faso")
burkinafaso_hki_data.columns
# Out:
# Index(['Region*', 'Submitted HKI Data for Target Population in 2021(round 1)',
#        'Region*.1',
#        'Submitted HKI Data for Target Population in 2021(round 2)',
#        'Population according to WorldPop Demographic database 2021',
#        'Percentage difference',
#        ' Population according to WorldPop Top Down Constrained model ',
#        'Percentage difference.1', 'Population according to Facebook HRSL',
#        'Percentage difference.2',
#        ' Population according to WorldPop Bottom-Up ',
#        'Percentage difference.3', 'Average across all alternative estimates',
#        'Percentage difference.4'],
#       dtype='object')

# %%
burkinafaso_hki_data=burkinafaso_hki_data[["Region*","Submitted HKI Data for Target Population in 2021(round 2)"]]
burkinafaso_hki_data
# Out:
#               Region*  \
# 0   Boucle du Mouhoun
# 1              Centre
# 2         Centre-Nord
# 3                 Est
# 4                Nord
# 5               Sahel
# 6        Centre-Ouest
# 7          Centre-Sud
# 8       Hauts-Bassins
# 9     Plateau-Central
# 10          Sud-Ouest
# 11         Centre-Est
# 12           Cascades
#
#     Submitted HKI Data for Target Population in 2021(round 2)
# 0                                              340955
# 1                                              138102
# 2                                              380936
# 3                                              286912
# 4                                              305243
# 5                                              283016
# 6                                              146891
# 7                                              339817
# 8                                              324745
# 9                                              291458
# ...

# %% [markdown]
# Rename column names

# %%
burkinafaso_hki_output=burkinafaso_hki_output.rename(columns={"ADM1_FR":"Admin_level1"})
burkinafaso_hki_data  =  burkinafaso_hki_data.rename(columns= {"Region*": "Admin_level1" })

# %% [markdown]
# Use concat to combine

# %%
burkinafaso_hki_merged=pd.merge(burkinafaso_hki_data,burkinafaso_hki_output,on=["Admin_level1"])
burkinafaso_hki_merged
# Out:
#          Admin_level1  \
# 0   Boucle du Mouhoun
# 1              Centre
# 2         Centre-Nord
# 3                 Est
# 4                Nord
# 5               Sahel
# 6        Centre-Ouest
# 7          Centre-Sud
# 8       Hauts-Bassins
# 9     Plateau-Central
# 10          Sud-Ouest
# 11         Centre-Est
# 12           Cascades
#
#     Submitted HKI Data for Target Population in 2021(round 2)  \
# 0                                              340955
# 1                                              138102
# 2                                              380936
# 3                                              286912
# 4                                              305243
# 5                                              283016
# 6                                              146891
# 7                                              339817
# 8                                              324745
# 9                                              291458
# ...

# %% [markdown]
# Calculate percentage differences

# %%
burkinafaso_hki_merged["cons_perc_difference"]  = ((burkinafaso_hki_merged["worldpop_cons_6-59_months"]  - burkinafaso_hki_merged["Submitted HKI Data for Target Population in 2021(round 2)"])  /  burkinafaso_hki_merged["Submitted HKI Data for Target Population in 2021(round 2)"])
burkinafaso_hki_merged["wopr_perc_difference"]  = ((burkinafaso_hki_merged["worldpop_wopr_6-59_months"]  -  burkinafaso_hki_merged["Submitted HKI Data for Target Population in 2021(round 2)"])  /  burkinafaso_hki_merged["Submitted HKI Data for Target Population in 2021(round 2)"])
burkinafaso_hki_merged["meta_perc_difference"]  = ((burkinafaso_hki_merged["facebook_6-59_months"]  - burkinafaso_hki_merged["Submitted HKI Data for Target Population in 2021(round 2)"])  /  burkinafaso_hki_merged["Submitted HKI Data for Target Population in 2021(round 2)"])

# %% [markdown]
# Save to file

# %%
burkinafaso_hki_merged.columns
# Out:
# Index(['Admin_level1',
#        'Submitted HKI Data for Target Population in 2021(round 2)',
#        'worldpop_cons_u5_bfa_f_0_4_2022_1km_UNadj_constrained_sum',
#        'worldpop_cons_u5_bfa_m_0_4_2022_1km_UNadj_constrained_sum',
#        'worldpop_cons_u5_sum_total', 'worldpop_cons_6-59_months',
#        'worldpop_wopr_u5_sum', 'worldpop_wopr_6-59_months', 'facebook_u5_sum',
#        'facebook_6-59_months', 'cons_perc_difference', 'wopr_perc_difference',
#        'meta_perc_difference'],
#       dtype='object')

# %%
ordered_col_names=[
        'Admin_level1',
        'Submitted HKI Data for Target Population in 2021(round 2)',
       'worldpop_cons_6-59_months',
       'cons_perc_difference',    
       'worldpop_wopr_6-59_months', 
       'wopr_perc_difference',
       'facebook_6-59_months', 
       'meta_perc_difference' 
 ]

# %%
burkinafaso_hki_merged=burkinafaso_hki_merged[ordered_col_names]
burkinafaso_hki_merged
# Out:
#          Admin_level1  \
# 0   Boucle du Mouhoun
# 1              Centre
# 2         Centre-Nord
# 3                 Est
# 4                Nord
# 5               Sahel
# 6        Centre-Ouest
# 7          Centre-Sud
# 8       Hauts-Bassins
# 9     Plateau-Central
# 10          Sud-Ouest
# 11         Centre-Est
# 12           Cascades
#
#     Submitted HKI Data for Target Population in 2021(round 2)  \
# 0                                              340955
# 1                                              138102
# 2                                              380936
# 3                                              286912
# 4                                              305243
# 5                                              283016
# 6                                              146891
# 7                                              339817
# 8                                              324745
# 9                                              291458
# ...

# %%
burkinafaso_hki_merged.to_excel(writer ,sheet_name="HKI_Burkina Faso",index=False)

# %% [markdown]
# # Close

# %%
writer.close()
